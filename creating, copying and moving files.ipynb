# %%
#creating folders
import os

# %%
os.mkdir(r'/Users/varun/Desktop/python 2026\Example_folder')
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 os.mkdir(r'/Users/varun/Desktop/python 2026\Example_folder')
#
# FileExistsError: [Errno 17] File exists: '/Users/varun/Desktop/python 2026\\Example_folder'

# %%
if os.path.exists(r'/Users/varun/Desktop/python 2026\Example_folder2'):
    os.mkdir(r'/Users/varun/Desktop/python 2026\Example_forder2')

# %%
# copy and move files
import os
import shutil
path = r'/Users/varun/Desktop/python 2026/fake_file.txt'

# %%
shutil.move(path, r'/Users/varun/Desktop/python 2026/Example_folder/fake_file.csv')
# Out:
# '/Users/varun/Desktop/python 2026/Example_folder/fake_file.csv'

# %%
shutil.copy(path, r'/Users/varun/Desktop/python 2026/Example_folder/fake_file.txt')
# Out:
# '/Users/varun/Desktop/python 2026/Example_folder/fake_file.txt'
